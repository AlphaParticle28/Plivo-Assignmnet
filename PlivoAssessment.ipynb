# %% [markdown]
# <a href="https://colab.research.google.com/github/AlphaParticle28/Plivo-Assignmnet/blob/main/PlivoAssessment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python /content/pii_ner_assignment/src/train.py
# Out:
# 2025-11-23 15:26:20.622744: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763911580.641624    9318 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763911580.647471    9318 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763911580.662125    9318 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python /content/pii_ner_assignment/src/predict.py
# Out:
# 2025-11-23 15:28:28.840012: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763911708.871629    9857 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763911708.881939    9857 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763911708.909484    9857 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python /content/pii_ner_assignment/src/eval_span_f1.py
# Out:
# Per-entity metrics:
# ADDRESS         P=0.000 R=0.000 F1=0.000
# CREDIT_CARD     P=1.000 R=1.000 F1=1.000
# DATE            P=1.000 R=0.700 F1=0.824
# DATE_OF_BIRTH   P=0.000 R=0.000 F1=0.000
# EMAIL           P=1.000 R=1.000 F1=1.000
# LOCATION        P=1.000 R=1.000 F1=1.000
# PERSON_NAME     P=1.000 R=1.000 F1=1.000
# PHONE           P=1.000 R=1.000 F1=1.000
#
# Macro-F1: 0.728
#
# PII-only metrics: P=1.000 R=0.974 F1=0.987
# Non-PII metrics: P=1.000 R=0.231 F1=0.375

# %%
# !python /content/pii_ner_assignment/src/measure_latency.py
# Out:
# 2025-11-23 15:28:42.541405: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763911722.560711    9930 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763911722.566836    9930 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763911722.581532    9930 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
